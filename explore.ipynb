# %% [markdown]
# ### Homework Rakamin Trial Class - Mini Case

# %% [markdown]
# # Mengukur Performa Penjualan Ritel Online

# %% [markdown]
# ## Load Data

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("online_retail_II.csv")
df
# Out:
#         Invoice StockCode  ... Customer ID         Country
# 0        489434     85048  ...     13085.0  United Kingdom
# 1        489434    79323P  ...     13085.0  United Kingdom
# 2        489434    79323W  ...     13085.0  United Kingdom
# 3        489434     22041  ...     13085.0  United Kingdom
# 4        489434     21232  ...     13085.0  United Kingdom
# ...         ...       ...  ...         ...             ...
# 1067366  581587     22899  ...     12680.0          France
# 1067367  581587     23254  ...     12680.0          France
# 1067368  581587     23255  ...     12680.0          France
# 1067369  581587     22138  ...     12680.0          France
# 1067370  581587      POST  ...     12680.0          France
#
# [1067371 rows x 8 columns]

# %% [markdown]
# ## Section 1

# %% [markdown]
# ### Create New Feature: Year

# %%
df["InvoiceDate"] = pd.to_datetime(df["InvoiceDate"], format="%Y/%m/%d %H:%M:%S")
df.dtypes
df["Year"] = df["InvoiceDate"].dt.year
df
# Out:
#         Invoice StockCode  ...         Country  Year
# 0        489434     85048  ...  United Kingdom  2009
# 1        489434    79323P  ...  United Kingdom  2009
# 2        489434    79323W  ...  United Kingdom  2009
# 3        489434     22041  ...  United Kingdom  2009
# 4        489434     21232  ...  United Kingdom  2009
# ...         ...       ...  ...             ...   ...
# 1067366  581587     22899  ...          France  2011
# 1067367  581587     23254  ...          France  2011
# 1067368  581587     23255  ...          France  2011
# 1067369  581587     22138  ...          France  2011
# 1067370  581587      POST  ...          France  2011
#
# [1067371 rows x 9 columns]

# %% [markdown]
# ### Filtering Data

# %%
sales = df[~(df["Invoice"].str.contains("C")) & (df["Quantity"] > 0)]
sales
# Out:
#         Invoice StockCode  ...         Country  Year
# 0        489434     85048  ...  United Kingdom  2009
# 1        489434    79323P  ...  United Kingdom  2009
# 2        489434    79323W  ...  United Kingdom  2009
# 3        489434     22041  ...  United Kingdom  2009
# 4        489434     21232  ...  United Kingdom  2009
# ...         ...       ...  ...             ...   ...
# 1067366  581587     22899  ...          France  2011
# 1067367  581587     23254  ...          France  2011
# 1067368  581587     23255  ...          France  2011
# 1067369  581587     22138  ...          France  2011
# 1067370  581587      POST  ...          France  2011
#
# [1044420 rows x 9 columns]

# %% [markdown]
# ### Create New Feature: Revenue

# %%
sales["Revenue"] = sales["Quantity"]*sales["Price"]
sales
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#         Invoice StockCode  ...  Year  Revenue
# 0        489434     85048  ...  2009    83.40
# 1        489434    79323P  ...  2009    81.00
# 2        489434    79323W  ...  2009    81.00
# 3        489434     22041  ...  2009   100.80
# 4        489434     21232  ...  2009    30.00
# ...         ...       ...  ...   ...      ...
# 1067366  581587     22899  ...  2011    12.60
# 1067367  581587     23254  ...  2011    16.60
# 1067368  581587     23255  ...  2011    16.60
# 1067369  581587     22138  ...  2011    14.85
# 1067370  581587      POST  ...  2011    18.00
#
# ...

# %% [markdown]
# ### Average of Revenue per Year

# %%
plt.rcParams['figure.figsize'] = [9, 5]

plt.title("Average Revenue per Year")
sales.set_index("Year", inplace=True)
plt.xlabel("Year")
plt.ylabel("Revenue")
sales.groupby("Year")["Revenue"].mean().plot()

# %% [markdown]
# ### Interpretation

# %% [markdown]
# Rata-rata pendapatan setiap tahun dari 2009-2011 terus meningkat, terjadi peningkatan drastis dari tahun 2009-2010, dan peningkatan berkala dari 2010-2011.

# %% [markdown]
# ## Section 2

# %% [markdown]
# ### Filtering Data

# %%
finished = sales[(sales["Customer ID"] != "") | (sales["Customer ID"] != None)]
sales
# Out:
#      Invoice StockCode  ...         Country  Revenue
# Year                    ...
# 2009  489434     85048  ...  United Kingdom    83.40
# 2009  489434    79323P  ...  United Kingdom    81.00
# 2009  489434    79323W  ...  United Kingdom    81.00
# 2009  489434     22041  ...  United Kingdom   100.80
# 2009  489434     21232  ...  United Kingdom    30.00
# ...      ...       ...  ...             ...      ...
# 2011  581587     22899  ...          France    12.60
# 2011  581587     23254  ...          France    16.60
# 2011  581587     23255  ...          France    16.60
# 2011  581587     22138  ...          France    14.85
# 2011  581587      POST  ...          France    18.00
#
# [1044420 rows x 9 columns]

# %% [markdown]
# #### Customers who finished their purchases

# %%
purchased = pd.DataFrame()
purchased["done"] = finished.groupby("Year")["Invoice"].count()
purchased
# Out:
#         done
# Year
# 2009   44123
# 2010  510694
# 2011  489603

# %% [markdown]
# #### Customers who canceled their purchases

# %%
dfc = df[df["Invoice"].str.contains("C")]
dfc
cancel = pd.DataFrame()
cancel["cancelled"] = dfc.groupby("Year")["Invoice"].count()
cancel
# Out:
#       cancelled
# Year
# 2009       1015
# 2010       9919
# 2011       8560

# %% [markdown]
# ### Number of Finished and Canceled Transactions Each Year

# %%
plt.title("Number of Finished and Canceled Transactions Each Year")
plt.xlabel("Year")
plt.ylabel("Total")

plt.plot(purchased, label="Finished", color="green")
plt.plot(cancel, label="Canceled", color="red")
plt.legend()

# %% [markdown]
# ### Cancellation Rate

# %%
from pandas.core.tools.numeric import to_numeric
crate = pd.DataFrame()
crate["Year"] = cancel.index

crate.set_index("Year", inplace=True)
totalcustomer = df["Customer ID"].sum()
totalcustomer

crate["Cancel Rate"] = cancel["cancelled"]/totalcustomer*100
crate

plt.title("Cancellation Rate")
plt.xlabel("Year")
plt.ylabel("Persen")
plt.plot(crate, color="red")

# %% [markdown]
# ### Interpretation

# %% [markdown]
# Rasio batal beli dan jumlah sukses beli meningkat drastis dari 2009-2010, dan menurun berkala dari tahun 2010-2011. Rasio batal beli ikut meningkat seiring dengan meningkatnya jumlah customer yang sukses beli, begitu juga sebaliknya.
